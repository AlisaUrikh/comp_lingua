# %% [markdown]
# <a href="https://colab.research.google.com/github/AlisaUrikh/comp_lingua/blob/main/word2vec/gensim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/AlisaUrikh/comp_lingua/refs/heads/main/word2vec/gordost_i_predubejdenie.txt
# Out:
# --2024-12-19 00:36:20--  https://raw.githubusercontent.com/AlisaUrikh/comp_lingua/refs/heads/main/word2vec/gordost_i_predubejdenie.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1296974 (1.2M) [text/plain]
# Saving to: ‘gordost_i_predubejdenie.txt’
#
# gordost_i_predubejd 100%[===================>]   1.24M  --.-KB/s    in 0.01s
#
# 2024-12-19 00:36:20 (115 MB/s) - ‘gordost_i_predubejdenie.txt’ saved [1296974/1296974]

# %%
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec

# %%
with open("gordost_i_predubejdenie.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
sentences = [simple_preprocess(sentence) for sentence in text.splitlines() if sentence]

# %%
model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

# %%
model.wv.most_similar("гордость", topn=5)
# Out:
# [('насколько', 0.9996702671051025),
#  ('до', 0.9996605515480042),
#  ('хотя', 0.9996541142463684),
#  ('теперь', 0.9996522665023804),
#  ('всех', 0.9996515512466431)]

# %%
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
stop_words = set(stopwords.words('russian'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sentences = [
    [word for word in simple_preprocess(sentence) if word not in stop_words]
    for sentence in text.splitlines() if sentence
]

# %%
model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

# %%
model.wv.most_similar("гордость", topn=5)
# Out:
# [('сказать', 0.9980877637863159),
#  ('которая', 0.9979808926582336),
#  ('мистер', 0.9979626536369324),
#  ('столь', 0.9979386925697327),
#  ('время', 0.9979302287101746)]

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

# %%
dictionary = Dictionary(sentences)
corpus = [dictionary.doc2bow(sentence) for sentence in sentences]

# %%
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# %%
topics = lda_model.print_topics(num_words=5)
for idx, topic in topics:
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.016*"элизабет" + 0.012*"дарси" + 0.007*"это" + 0.006*"миссис" + 0.006*"беннет"
# Topic 1: 0.009*"элизабет" + 0.009*"это" + 0.006*"джейн" + 0.005*"письмо" + 0.004*"дарси"
# Topic 2: 0.009*"элизабет" + 0.006*"дарси" + 0.005*"бингли" + 0.004*"джейн" + 0.003*"леди"
# Topic 3: 0.010*"это" + 0.010*"элизабет" + 0.008*"дарси" + 0.007*"мистер" + 0.006*"беннет"
# Topic 4: 0.010*"дарси" + 0.009*"это" + 0.008*"элизабет" + 0.006*"лиззи" + 0.006*"джейн"

# %%
# !pip install pyLDAvis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 40.2 MB/s eta 0:00:00
# ...

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

lda_display = gensimvis.prepare(lda_model, corpus, dictionary, sort_topics=False)

pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2911372074048047209223475019" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
pyLDAvis.save_html(lda_display, 'lda_visualization.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
